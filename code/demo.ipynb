# %%
# General imports
import os
import sys
import math
import json
import numpy as np
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

# Sinergym
import sinergym
from src.wrappers import SinergymWrapper
from src.rewards import FangerReward

# Model
import ray
import torch.nn as nn
from ray.rllib.algorithms.ppo import PPO


# Flag: weahter to use Active RL or not
DESC = 'PPO_activation_gamma99_'

# %%
# Remove old environments
# !find . -type d -name 'Eplus-env-*' -exec rm -rf {} +

# %%
# Add the EnergyPlus path to the system path
sys.path.append('./EnergyPlus-23-1-0')
# Set the EnergyPlus path as an environment variable
os.environ['EPLUS_PATH'] = './EnergyPlus-23-1-0'
# Ignore deprecation warnings
os.environ['PYTHONWARNINGS'] = 'ignore::DeprecationWarning'

# %%
# Environment ID
env_id = "Eplus-5zone-hot-continuous-stochastic-v1"

# Weather
weather_files = ['USA_AZ_Davis-Monthan.AFB.722745_TMY3.epw']

# mu, sigma and theta for the weather variability
# In the original version, weather_variability was a triple (mu, sigma, theta)
# that only affected the drybulb (outdoor temperature), while now it is a dictionary
# with the mean, sigma and theta for each weather variable we want to vary.
# NOTE: Check apply_weather_variability method in CustomModelJSON class
weather_variability = {
    'drybulb': np.array([5.53173187e+00, 0.00000000e+00, 2.55034944e-03]), 
    'relhum': np.array([1.73128872e+01, 0.00000000e+00, 2.31712760e-03]), 
    'winddir': np.array([7.39984654e+01, 0.00000000e+00, 4.02298013e-04]), 
    'dirnorrad': np.array([3.39506556e+02, 0.00000000e+00, 9.78192172e-04]), 
    'windspd': np.array([1.64655725e+00, 0.00000000e+00, 3.45045547e-04])
}

# Initialize with a single factor
initial_factors = ['drybulb']
# Define all factors you eventually want to include
all_factors = ['drybulb', 'relhum', 'winddir', 'dirnorrad', 'windspd']

# Custom reward derived from Fanger's comfort model.
# This extends the LinearReward class from sinergym adding ppd and occupancy variables.
reward = FangerReward
reward_kwargs={
    'temperature_variables': ['air_temperature'],
    'energy_variables': ['HVAC_electricity_demand_rate'],
    'range_comfort_winter': [20, 23],
    'range_comfort_summer': [23, 26],
    'energy_weight': 0.1,
    'ppd_variable': 'Zone Thermal Comfort Fanger Model PPD(SPACE1-1 PEOPLE 1)',
    'occupancy_variable': 'Zone People Occupant Count(SPACE1-1)'
}

# Environment configuration
env_config = {
    'env_id': env_id,
    'weather_files': weather_files,
    'reward': reward,
    'reward_kwargs': reward_kwargs,
    'weather_variability': weather_variability, #{'drybulb': weather_variability['drybulb']},
}

# %% [markdown]
# I adopted the strategy of Curriculum Learning. That said, the training will start with a simpler version of the environment, where only the external temperature varies. Through epochs, more external factors are added, making the environment more complex. This is done by modifying the weather_variability in a dynamic way.

# %%
# Initialize ray
ray.init(ignore_reinit_error=True)

# Get the default configuration
config = PPO.get_default_config()

# Environment specific configuration
config['env'] = SinergymWrapper
config['env_config'] = env_config

# Hardware specific configuration
config['num_gpus'] = 1
config['use_gpu'] = True

# Model configuration
# config['model']['use_attention'] = True
config['model']['fcnet_activation'] = lambda: nn.Sequential(nn.Tanh(), nn.Dropout(p=0.3))

# Training configuration
# config['train_batch_size'] = 4000
# config['entropu_coeff'] = 0.02                  # Regularization term to encourage exploration                  
# config['rollout_fragment_length'] = "auto"
# config['sgd_minibatch_size'] = 256
# config['clip_param'] = 0.2
# config['gamma'] = 0.80                            # Best discount factor for the task is 0.8
#config['lr'] = 1e-4

# Initialize the trainer
trainer = PPO(config=config)
# Out:
# 2024-03-14 21:34:44,406	INFO worker.py:1724 -- Started a local Ray instance.
# /home/luigi/Documents/SmartEnergyOptimizationRL/.venv/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:483: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/luigi/Documents/SmartEnergyOptimizationRL/.venv/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/luigi/Documents/SmartEnergyOptimizationRL/.venv/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/luigi/Documents/SmartEnergyOptimizationRL/.venv/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (RolloutWorker pid=15344) #==============================================================================================#
# (RolloutWorker pid=15344) [ENVIRONMENT] (INFO) : Creating Gymnasium environment... [5zone-hot-continuous-stochastic-v1]
# (RolloutWorker pid=15344) #==============================================================================================#
# (RolloutWorker pid=15343) [MODELING] (INFO) : Experiment working directory created [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-5zone-hot-continuous-stochastic-v1-res2]
# (RolloutWorker pid=15343) [MODELING] (INFO) : Model Config is correct.
# (RolloutWorker pid=15343) [MODELING] (INFO) : Updated building model with whole Output:Variable available names
# (RolloutWorker pid=15343) [MODELING] (INFO) : Updated building model with whole Output:Meter available names
# (RolloutWorker pid=15343) [MODELING] (INFO) : runperiod established: {'start_day': 1, 'start_month': 1, 'start_year': 1991, 'end_day': 31, 'end_month': 12, 'end_year': 1991, 'start_weekday': 0, 'n_steps_per_hour': 4}
# (RolloutWorker pid=15343) [MODELING] (INFO) : Episode length (seconds): 31536000.0
# (RolloutWorker pid=15343) [MODELING] (INFO) : timestep size (seconds): 900.0
# (RolloutWorker pid=15343) [MODELING] (INFO) : timesteps per episode: 35040
# (RolloutWorker pid=15343) [REWARD] (INFO) : Reward function initialized.
# (RolloutWorker pid=15343) [ENVIRONMENT] (INFO) : Environment 5zone-hot-continuous-stochastic-v1 created successfully.
# (RolloutWorker pid=15343) [WRAPPER NormalizeObservation] (INFO) : wrapper initialized.
# (RolloutWorker pid=15343) #----------------------------------------------------------------------------------------------#
# (RolloutWorker pid=15343) [ENVIRONMENT] (INFO) : Starting a new episode... [5zone-hot-continuous-stochastic-v1] [Episode 1]
# (RolloutWorker pid=15343) #----------------------------------------------------------------------------------------------#
# (RolloutWorker pid=15343) [MODELING] (INFO) : Episode directory created [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res2/Eplus-env-sub_run1]
# (RolloutWorker pid=15343) [MODELING] (INFO) : Weather file USA_AZ_Davis-Monthan.AFB.722745_TMY3.epw used.
# (RolloutWorker pid=15343) [MODELING] (INFO) : Adapting weather to building model. [USA_AZ_Davis-Monthan.AFB.722745_TMY3.epw]
# (RolloutWorker pid=15344) /home/luigi/Documents/SmartEnergyOptimizationRL/.venv/lib/python3.10/site-packages/gymnasium/wrappers/compatibility.py:60: DeprecationWarning: WARN: The `gymnasium.make(..., apply_api_compatibility=...)` parameter is deprecated and will be removed in v1.0. Instead use `gymnasium.make('GymV21Environment-v0', env_name=...)` or `from shimmy import GymV21CompatibilityV0`
# (RolloutWorker pid=15344)   logger.deprecation(
# (RolloutWorker pid=15343) 2024-03-14 21:34:49,289	WARNING utils.py:160 -- `config.auto_wrap_old_gym_envs` is activated AND you seem to have provided an old gym-API environment. RLlib will therefore try to auto-fix the following error. However, please consider switching over to the new `gymnasium` APIs:
# (RolloutWorker pid=15343) Your environment ({}) does not abide to the new gymnasium-style API!
# (RolloutWorker pid=15343) From Ray 2.3 on, RLlib only supports the new (gym>=0.26 or gymnasium) Env APIs.
# (RolloutWorker pid=15343) {}
# (RolloutWorker pid=15343) Learn more about the most important changes here:
# (RolloutWorker pid=15343) https://github.com/openai/gym and here: https://github.com/Farama-Foundation/Gymnasium
# (RolloutWorker pid=15343)
# (RolloutWorker pid=15343) In order to fix this problem, do the following:
# (RolloutWorker pid=15343)
# (RolloutWorker pid=15343) 1) Run `pip install gymnasium` on your command line.
# (RolloutWorker pid=15343) 2) Change all your import statements in your code from
# (RolloutWorker pid=15343)    `import gym` -> `import gymnasium as gym` OR
# (RolloutWorker pid=15343)    `from gym.space import Discrete` -> `from gymnasium.spaces import Discrete`
# (RolloutWorker pid=15343)
# (RolloutWorker pid=15343) For your custom (single agent) gym.Env classes:
# (RolloutWorker pid=15343) 3.1) Either wrap your old Env class via the provided `from gymnasium.wrappers import
# (RolloutWorker pid=15343)      EnvCompatibility` wrapper class.
# (RolloutWorker pid=15343) 3.2) Alternatively to 3.1:
# (RolloutWorker pid=15343)  - Change your `reset()` method to have the call signature 'def reset(self, *,
# (RolloutWorker pid=15343)    seed=None, options=None)'
# (RolloutWorker pid=15343)  - Return an additional info dict (empty dict should be fine) from your `reset()`
# (RolloutWorker pid=15343)    method.
# (RolloutWorker pid=15343)  - Return an additional `truncated` flag from your `step()` method (between `done` and
# (RolloutWorker pid=15343)    `info`). This flag should indicate, whether the episode was terminated prematurely
# (RolloutWorker pid=15343)    due to some time constraint or other kind of horizon setting.
# (RolloutWorker pid=15343)
# (RolloutWorker pid=15343) For your custom RLlib `MultiAgentEnv` classes:
# (RolloutWorker pid=15343) 4.1) Either wrap your old MultiAgentEnv via the provided
# (RolloutWorker pid=15343)      `from ray.rllib.env.wrappers.multi_agent_env_compatibility import
# (RolloutWorker pid=15343)      MultiAgentEnvCompatibility` wrapper class.
# (RolloutWorker pid=15343) 4.2) Alternatively to 4.1:
# (RolloutWorker pid=15343)  - Change your `reset()` method to have the call signature
# (RolloutWorker pid=15343)    'def reset(self, *, seed=None, options=None)'
# (RolloutWorker pid=15343)  - Return an additional per-agent info dict (empty dict should be fine) from your
# (RolloutWorker pid=15343)    `reset()` method.
# (RolloutWorker pid=15343)  - Rename `dones` into `terminateds` and only set this to True, if the episode is really
# (RolloutWorker pid=15343)    done (as opposed to has been terminated prematurely due to some horizon/time-limit
# (RolloutWorker pid=15343)    setting).
# (RolloutWorker pid=15343)  - Return an additional `truncateds` per-agent dictionary flag from your `step()`
# (RolloutWorker pid=15343)    method, including the `__all__` key (100% analogous to your `dones/terminateds`
# (RolloutWorker pid=15343)    per-agent dict).
# (RolloutWorker pid=15343)    Return this new `truncateds` dict between `dones/terminateds` and `infos`. This
# (RolloutWorker pid=15343)    flag should indicate, whether the episode (for some agent or all agents) was
# (RolloutWorker pid=15343)    terminated prematurely due to some time constraint or other kind of horizon setting.
# (RolloutWorker pid=15343)
# (RolloutWorker pid=15344) [ENVIRONMENT] (INFO) : Saving episode output path... [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run1/output]
# (RolloutWorker pid=15343) [SIMULATOR] (INFO) : Running EnergyPlus with args: ['-w', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res2/Eplus-env-sub_run1/USA_AZ_Davis-Monthan.AFB.722745_TMY3_Random_1.64655725_0.0_0.000345045547.epw', '-d', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res2/Eplus-env-sub_run1/output', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res2/Eplus-env-sub_run1/5ZoneAutoDXVAV.epJSON']
# (RolloutWorker pid=15343) [ENVIRONMENT] (INFO) : Episode 1 started.
# (RolloutWorker pid=15343) [SIMULATOR] (INFO) : handlers initialized.
# (RolloutWorker pid=15343) [SIMULATOR] (INFO) : handlers are ready.
# (RolloutWorker pid=15343) [SIMULATOR] (INFO) : System is ready.
# Progress: |*--------------------------------------------------------------------------------------------------| 1%
# Progress: |**-------------------------------------------------------------------------------------------------| 2%
# Progress: |**-------------------------------------------------------------------------------------------------| 2%
# Progress: |****-----------------------------------------------------------------------------------------------| 4%
# Progress: |*****----------------------------------------------------------------------------------------------| 5%
# Progress: |*******--------------------------------------------------------------------------------------------| 7%
# Progress: |********-------------------------------------------------------------------------------------------| 8%
# Progress: |*******--------------------------------------------------------------------------------------------| 7%
# Progress: |********-------------------------------------------------------------------------------------------| 8%
# Progress: |***********----------------------------------------------------------------------------------------| 11%
# Progress: |***********----------------------------------------------------------------------------------------| 11%
# Progress: |************---------------------------------------------------------------------------------------| 12%
# Progress: |**************-------------------------------------------------------------------------------------| 14%
# Progress: |****************-----------------------------------------------------------------------------------| 16%
# Progress: |***************------------------------------------------------------------------------------------| 15%
# Progress: |****************-----------------------------------------------------------------------------------| 16%
# Progress: |*******************--------------------------------------------------------------------------------| 19%
# Progress: |********************-------------------------------------------------------------------------------| 20%
# Progress: |**********************-----------------------------------------------------------------------------| 22%
# Progress: |***********************----------------------------------------------------------------------------| 23%
# Progress: |***********************----------------------------------------------------------------------------| 23%
# Progress: |**********************-----------------------------------------------------------------------------| 22%
# Progress: |*************************--------------------------------------------------------------------------| 25%
# Progress: |**************************-------------------------------------------------------------------------| 26%
# Progress: |**************************-------------------------------------------------------------------------| 26%
# Progress: |****************************-----------------------------------------------------------------------| 29%
# Progress: |****************************-----------------------------------------------------------------------| 29%
# Progress: |****************************-----------------------------------------------------------------------| 29%
# Progress: |*******************************--------------------------------------------------------------------| 31%
# Progress: |********************************-------------------------------------------------------------------| 32%
# Progress: |**********************************-----------------------------------------------------------------| 34%
# Progress: |***********************************----------------------------------------------------------------| 35%
# Progress: |*************************************--------------------------------------------------------------| 37%
# Progress: |*************************************--------------------------------------------------------------| 37%
# Progress: |****************************************-----------------------------------------------------------| 40%
# Progress: |****************************************-----------------------------------------------------------| 40%
# Progress: |****************************************-----------------------------------------------------------| 40%
# Progress: |*******************************************--------------------------------------------------------| 43%
# Progress: |*******************************************--------------------------------------------------------| 43%
# Progress: |**********************************************-----------------------------------------------------| 46%
# Progress: |**********************************************-----------------------------------------------------| 46%
# Progress: |**********************************************-----------------------------------------------------| 46%
# Progress: |*************************************************--------------------------------------------------| 49%
# Progress: |*************************************************--------------------------------------------------| 49%
# Progress: |****************************************************-----------------------------------------------| 52%
# Progress: |***************************************************------------------------------------------------| 51%
# Progress: |*******************************************************--------------------------------------------| 55%
# Progress: |*******************************************************--------------------------------------------| 55%
# Progress: |*********************************************************------------------------------------------| 58%
# Progress: |*********************************************************------------------------------------------| 58%
# Progress: |**************************************************************-------------------------------------| 62%
# Progress: |**************************************************************-------------------------------------| 62%
# Progress: |*****************************************************************----------------------------------| 65%
# Progress: |*****************************************************************----------------------------------| 65%
# Progress: |*****************************************************************----------------------------------| 65%
# Progress: |*********************************************************************------------------------------| 69%
# Progress: |********************************************************************-------------------------------| 68%
# Progress: |*********************************************************************------------------------------| 69%
# Progress: |************************************************************************---------------------------| 72%
# Progress: |***********************************************************************----------------------------| 71%
# Progress: |***************************************************************************------------------------| 75%
# Progress: |***************************************************************************------------------------| 75%
# Progress: |******************************************************************************---------------------| 78%
# Progress: |******************************************************************************---------------------| 78%
# Progress: |*********************************************************************************------------------| 81%
# Progress: |*********************************************************************************------------------| 81%
# Progress: |************************************************************************************---------------| 84%
# Progress: |************************************************************************************---------------| 84%
# Progress: |***************************************************************************************------------| 87%
# Progress: |***************************************************************************************------------| 87%
# Progress: |***************************************************************************************------------| 87%
# Progress: |******************************************************************************************---------| 90%
# Progress: |******************************************************************************************---------| 90%
# Progress: |*********************************************************************************************------| 93%
# Progress: |*********************************************************************************************------| 93%
# Progress: |*********************************************************************************************------| 93%
# Progress: |************************************************************************************************---| 96%
# Progress: |************************************************************************************************---| 96%
# Progress: |***************************************************************************************************| 99%
# Progress: |***************************************************************************************************| 99%
# Progress: |***************************************************************************************************| 99%
# Progress: |***************************************************************************************************| 99%
# Progress: |***************************************************************************************************| 99%
# (RolloutWorker pid=15343) #==============================================================================================# [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (RolloutWorker pid=15343) [ENVIRONMENT] (INFO) : Creating Gymnasium environment... [5zone-hot-continuous-stochastic-v1]
# Progress: |**-------------------------------------------------------------------------------------------------| 2%
# Progress: |**-------------------------------------------------------------------------------------------------| 2%
# Progress: |*****----------------------------------------------------------------------------------------------| 5%
# Progress: |*****----------------------------------------------------------------------------------------------| 5%
# Progress: |*******--------------------------------------------------------------------------------------------| 7%
# Progress: |**********-----------------------------------------------------------------------------------------| 10%
# Progress: |**********-----------------------------------------------------------------------------------------| 10%
# Progress: |***********----------------------------------------------------------------------------------------| 11%
# Progress: |**************-------------------------------------------------------------------------------------| 14%
# Progress: |*************--------------------------------------------------------------------------------------| 13%
# Progress: |**************-------------------------------------------------------------------------------------| 14%
# Progress: |******************---------------------------------------------------------------------------------| 18%
# Progress: |****************-----------------------------------------------------------------------------------| 16%
# Progress: |*********************------------------------------------------------------------------------------| 21%
# Progress: |*******************--------------------------------------------------------------------------------| 19%
# Progress: |************************---------------------------------------------------------------------------| 24%
# (RolloutWorker pid=15344) [MODELING] (INFO) : Experiment working directory created [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1] [repeated 3x across cluster]
# (RolloutWorker pid=15344) [MODELING] (INFO) : Model Config is correct. [repeated 3x across cluster]
# (RolloutWorker pid=15344) [MODELING] (INFO) : Updated building model with whole Output:Variable available names [repeated 3x across cluster]
# (RolloutWorker pid=15344) [MODELING] (INFO) : Updated building model with whole Output:Meter available names [repeated 3x across cluster]
# (RolloutWorker pid=15344) [MODELING] (INFO) : runperiod established: {'start_day': 1, 'start_month': 1, 'start_year': 1991, 'end_day': 31, 'end_month': 12, 'end_year': 1991, 'start_weekday': 0, 'n_steps_per_hour': 4} [repeated 3x across cluster]
# (RolloutWorker pid=15344) [MODELING] (INFO) : Episode length (seconds): 31536000.0 [repeated 3x across cluster]
# (RolloutWorker pid=15344) [MODELING] (INFO) : timestep size (seconds): 900.0 [repeated 3x across cluster]
# (RolloutWorker pid=15344) [MODELING] (INFO) : timesteps per episode: 35040 [repeated 3x across cluster]
# (RolloutWorker pid=15344) [REWARD] (INFO) : Reward function initialized.
# (RolloutWorker pid=15344) [ENVIRONMENT] (INFO) : Environment 5zone-hot-continuous-stochastic-v1 created successfully.
# Progress: |**********************-----------------------------------------------------------------------------| 22%
# Progress: |**************************-------------------------------------------------------------------------| 26%
# (RolloutWorker pid=15344) [WRAPPER NormalizeObservation] (INFO) : wrapper initialized.
# (RolloutWorker pid=15344) #----------------------------------------------------------------------------------------------# [repeated 6x across cluster]
# (RolloutWorker pid=15344) [ENVIRONMENT] (INFO) : Starting a new episode... [5zone-hot-continuous-stochastic-v1] [Episode 2] [repeated 3x across cluster]
# (RolloutWorker pid=15344) [MODELING] (INFO) : Episode directory created [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run2] [repeated 3x across cluster]
# (RolloutWorker pid=15344) [MODELING] (INFO) : Weather file USA_AZ_Davis-Monthan.AFB.722745_TMY3.epw used. [repeated 3x across cluster]
# (RolloutWorker pid=15344) [MODELING] (INFO) : Adapting weather to building model. [USA_AZ_Davis-Monthan.AFB.722745_TMY3.epw] [repeated 3x across cluster]
# Progress: |*************************--------------------------------------------------------------------------| 25%
# Progress: |****************************-----------------------------------------------------------------------| 29%
# (RolloutWorker pid=15344) [ENVIRONMENT] (INFO) : Saving episode output path... [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run2/output] [repeated 3x across cluster]
# Progress: |***************************------------------------------------------------------------------------| 27%
# Progress: |******************************---------------------------------------------------------------------| 30%
# Progress: |**********************************-----------------------------------------------------------------| 34%
# (RolloutWorker pid=15344) [SIMULATOR] (INFO) : Running EnergyPlus with args: ['-w', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run2/USA_AZ_Davis-Monthan.AFB.722745_TMY3_Random_1.64655725_0.0_0.000345045547.epw', '-d', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run2/output', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run2/5ZoneAutoDXVAV.epJSON'] [repeated 3x across cluster]
# (RolloutWorker pid=15344) [ENVIRONMENT] (INFO) : Episode 2 started. [repeated 3x across cluster]
# Progress: |********************************-------------------------------------------------------------------| 32%
# Progress: |*************************************--------------------------------------------------------------| 37%
# (RolloutWorker pid=15344) [SIMULATOR] (INFO) : handlers initialized.
# (RolloutWorker pid=15344) [SIMULATOR] (INFO) : handlers are ready. [repeated 3x across cluster]
# (RolloutWorker pid=15344) [SIMULATOR] (INFO) : System is ready. [repeated 3x across cluster]
# Progress: |**-------------------------------------------------------------------------------------------------| 2%
# Progress: |***********************************----------------------------------------------------------------| 35%
# Progress: |***************************************------------------------------------------------------------| 39%
# Progress: |*************************************--------------------------------------------------------------| 37%
# Progress: |******************************************---------------------------------------------------------| 42%
# Progress: |********-------------------------------------------------------------------------------------------| 8%
# Progress: |********************************************-------------------------------------------------------| 44%
# Progress: |***********************************************----------------------------------------------------| 47%
# Progress: |********************************************-------------------------------------------------------| 44%
# Progress: |********************************************-------------------------------------------------------| 44%
# Progress: |*************************************************--------------------------------------------------| 49%
# Progress: |***********************************************----------------------------------------------------| 47%
# Progress: |****************************************************-----------------------------------------------| 52%
# Progress: |**************************************************-------------------------------------------------| 50%
# Progress: |****************************************************-----------------------------------------------| 52%
# Progress: |**************************************************-------------------------------------------------| 50%
# Progress: |********************************************************-------------------------------------------| 56%
# Progress: |****************************************************-----------------------------------------------| 52%
# Progress: |***********************************************************----------------------------------------| 59%
# Progress: |********************************************************-------------------------------------------| 56%
# Progress: |**************************************************************-------------------------------------| 62%
# Progress: |****************************-----------------------------------------------------------------------| 29%
# Progress: |***********************************************************----------------------------------------| 59%
# Progress: |***********************************************************----------------------------------------| 59%
# Progress: |****************************************************************-----------------------------------| 64%
# Progress: |********************************-------------------------------------------------------------------| 32%
# Progress: |**************************************************************-------------------------------------| 62%
# Progress: |*******************************************************************--------------------------------| 67%
# Progress: |*****************************************************************----------------------------------| 65%
# Progress: |**********************************************************************-----------------------------| 70%
# Progress: |********************************************************************-------------------------------| 68%
# Progress: |*************************************************************************--------------------------| 73%
# Progress: |***********************************************************************----------------------------| 71%
# Progress: |**************************************************************************-------------------------| 74%
# Progress: |***********************************************************************----------------------------| 71%
# Progress: |****************************************************************************-----------------------| 76%
# Progress: |**************************************************************************-------------------------| 74%
# Progress: |*******************************************************************************--------------------| 79%
# Progress: |*****************************************************************************----------------------| 77%
# Progress: |**********************************************************************************-----------------| 82%
# Progress: |********************************************************************************-------------------| 80%
# Progress: |*************************************************************************************--------------| 85%
# Progress: |***********************************************************************************----------------| 83%
# Progress: |**************************************************************************************-------------| 86%
# Progress: |*****************************************************************************************----------| 89%
# Progress: |**************************************************************************************-------------| 86%
# Progress: |*****************************************************************************************----------| 89%
# Progress: |********************************************************************************************-------| 92%
# Progress: |******************************************************************************************---------| 90%
# Progress: |***********************************************************************************************----| 95%
# Progress: |********************************************************************************************-------| 92%
# Progress: |************************************************************************************************---| 96%
# Progress: |***************************************************************************************************| 99%
# Progress: |************************************************************************************************---| 96%
# Progress: |***************************************************************************************************| 99%
# Progress: |**************************************************************************************************-| 98%
# Progress: |**************************************************************************************************-| 98%
# Progress: |***************************************************************************************************| 99%
# 2024-03-14 21:34:58,887	INFO trainable.py:164 -- Trainable.setup took 13.785 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-03-14 21:34:58,888	WARNING util.py:62 -- Install gputil for GPU system monitoring.

# %%
# Define a function to update weather_variability based on the current step
def update_weather_variability(step, initial_variability, factors, steps_per_increase):
    # Calculate the number of factors to include based on the current step
    num_factors = min(len(factors), (step // steps_per_increase) + 1)
    # Update weather_variability to only include the first 'num_factors' factors
    new_variability = {factor: initial_variability[factor] for factor in factors[:num_factors]}
    return new_variability

def save_latest_environment_config(config, file_path='data/latest_env_config.json'):
    # Convert NumPy arrays to lists for JSON serialization
    config_serializable = {}
    for key, value in config.items():
        if isinstance(value, np.ndarray):
            config_serializable[key] = value.tolist()
        else:
            config_serializable[key] = value
    
    with open(file_path, 'w') as f:
        json.dump(config_serializable, f)

# %%
# Initialize the rewards list and number of episodes
rewards = []
num_episodes = int(5e2)

# Increase complexity every steps_per_increase episodes
# 75% of the episodes will be used to increase the complexity
steps_per_increase = int(num_episodes * 0.8 / len(weather_variability))         

# Define the save paths
save_path = f'checkpoints/{DESC}{num_episodes}_episodes'
rewards_save_path = f'results/{DESC}rewards_{num_episodes}_episodes.npy'

# Iterate over num_episodes episodes
for i in tqdm(range(num_episodes), desc="Training"):
    # Update the environment complexity based on the current episode
    if i % steps_per_increase == 0 or i == 0:
        # Update the environment configuration (save the latest configuration to a file)
        new_config = update_weather_variability(i, weather_variability, all_factors, steps_per_increase)
        save_latest_environment_config(new_config)
        
    # Train the model
    result = trainer.train()

    # Check if the reward is not nan
    if not math.isnan(result['episode_reward_mean']):
        # Append the reward to the rewards list
        rewards.append(result['episode_reward_mean'])
    
    # Save the model every 10 episodes
    if i % 10 == 0:
        trainer.save(save_path)

# Save the array to a file
np.save(rewards_save_path, np.array(rewards))
# Out:
# Training:   0%|          | 0/500 [00:00<?, ?it/s]
# Progress: |**-------------------------------------------------------------------------------------------------| 2%
# Progress: |***------------------------------------------------------------------------------------------------| 3%
# Progress: |*****----------------------------------------------------------------------------------------------| 5%
# Progress: |*****----------------------------------------------------------------------------------------------| 5%
# Progress: |********-------------------------------------------------------------------------------------------| 8%
# Progress: |********-------------------------------------------------------------------------------------------| 8%
# Progress: |********-------------------------------------------------------------------------------------------| 8%
# Progress: |************---------------------------------------------------------------------------------------| 12%
# Progress: |***********----------------------------------------------------------------------------------------| 11%
# Progress: |***************------------------------------------------------------------------------------------| 15%
# Progress: |**************-------------------------------------------------------------------------------------| 14%
# Progress: |**************-------------------------------------------------------------------------------------| 14%
# Progress: |*******************--------------------------------------------------------------------------------| 19%
# Progress: |*****************----------------------------------------------------------------------------------| 17%
# Progress: |*****************----------------------------------------------------------------------------------| 17%
# Progress: |**********************-----------------------------------------------------------------------------| 22%
# Progress: |********************-------------------------------------------------------------------------------| 20%
# Progress: |**********************-----------------------------------------------------------------------------| 22%
# Progress: |***********************----------------------------------------------------------------------------| 23%
# Progress: |***********************----------------------------------------------------------------------------| 23%
# Progress: |**************************-------------------------------------------------------------------------| 26%
# Progress: |*************************--------------------------------------------------------------------------| 25%
# Progress: |**************************-------------------------------------------------------------------------| 26%
# Progress: |****************************-----------------------------------------------------------------------| 28%
# Progress: |****************************-----------------------------------------------------------------------| 28%
# Progress: |******************************---------------------------------------------------------------------| 30%
# Progress: |*******************************--------------------------------------------------------------------| 31%
# Progress: |*******************************--------------------------------------------------------------------| 31%
# Progress: |*********************************------------------------------------------------------------------| 33%
# Progress: |***********************************----------------------------------------------------------------| 35%
# Progress: |**************************************-------------------------------------------------------------| 38%
# Progress: |**************************************-------------------------------------------------------------| 38%
# Progress: |*****************************************----------------------------------------------------------| 41%
# Progress: |****************************************-----------------------------------------------------------| 40%
# Progress: |*******************************************--------------------------------------------------------| 43%
# Progress: |*******************************************--------------------------------------------------------| 43%
# Progress: |*********************************************------------------------------------------------------| 45%
# Progress: |********************************************-------------------------------------------------------| 44%
# Progress: |************************************************---------------------------------------------------| 48%
# Progress: |***********************************************----------------------------------------------------| 47%
# Progress: |**************************************************-------------------------------------------------| 50%
# Progress: |**************************************************-------------------------------------------------| 50%
# Progress: |**************************************************-------------------------------------------------| 50%
# Progress: |*****************************************************----------------------------------------------| 53%
# Progress: |****************************************************-----------------------------------------------| 52%
# Progress: |********************************************************-------------------------------------------| 56%
# Progress: |*******************************************************--------------------------------------------| 55%
# Progress: |*******************************************************--------------------------------------------| 55%
# Progress: |***********************************************************----------------------------------------| 59%
# Progress: |*********************************************************------------------------------------------| 58%
# Progress: |**************************************************************-------------------------------------| 62%
# Progress: |*************************************************************--------------------------------------| 61%
# Progress: |*****************************************************************----------------------------------| 65%
# Progress: |****************************************************************-----------------------------------| 64%
# Progress: |*****************************************************************----------------------------------| 65%
# Progress: |********************************************************************-------------------------------| 68%
# Progress: |******************************************************************---------------------------------| 66%
# Progress: |***********************************************************************----------------------------| 71%
# Progress: |*********************************************************************------------------------------| 69%
# Progress: |**************************************************************************-------------------------| 74%
# Progress: |************************************************************************---------------------------| 72%
# Progress: |************************************************************************---------------------------| 72%
# Progress: |*****************************************************************************----------------------| 77%
# Progress: |***************************************************************************------------------------| 75%
# Progress: |*******************************************************************************--------------------| 79%
# Progress: |******************************************************************************---------------------| 78%
# Progress: |*******************************************************************************--------------------| 79%
# Progress: |**********************************************************************************-----------------| 82%
# Progress: |*********************************************************************************------------------| 81%
# Progress: |**********************************************************************************-----------------| 82%
# Progress: |*************************************************************************************--------------| 85%
# Progress: |***********************************************************************************----------------| 83%
# Progress: |***************************************************************************************------------| 87%
# Progress: |**************************************************************************************-------------| 86%
# Progress: |****************************************************************************************-----------| 88%
# Progress: |******************************************************************************************---------| 90%
# Progress: |****************************************************************************************-----------| 88%
# Progress: |*****************************************************************************************----------| 89%
# Progress: |*********************************************************************************************------| 93%
# Progress: |*******************************************************************************************--------| 91%
# Progress: |************************************************************************************************---| 96%
# Progress: |*********************************************************************************************------| 93%
# Progress: |*********************************************************************************************------| 93%
# Progress: |**************************************************************************************************-| 98%
# Progress: |************************************************************************************************---| 96%
# Progress: |***************************************************************************************************| 99%
# (RolloutWorker pid=15343) #----------------------------------------------------------------------------------------------#
# (RolloutWorker pid=15343) [ENVIRONMENT] (INFO) : Starting a new episode... [5zone-hot-continuous-stochastic-v1] [Episode 4]
# (RolloutWorker pid=15343) #----------------------------------------------------------------------------------------------#
# (RolloutWorker pid=15343) [MODELING] (INFO) : Episode directory created [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res2/Eplus-env-sub_run4]
# Progress: |**************************************************************************************************-| 98%
# (RolloutWorker pid=15343) [MODELING] (INFO) : Weather file USA_AZ_Davis-Monthan.AFB.722745_TMY3.epw used.
# (RolloutWorker pid=15343) [MODELING] (INFO) : Adapting weather to building model. [USA_AZ_Davis-Monthan.AFB.722745_TMY3.epw]
# (RolloutWorker pid=15343) [ENVIRONMENT] (INFO) : Saving episode output path... [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res2/Eplus-env-sub_run4/output]
# (RolloutWorker pid=15343) [SIMULATOR] (INFO) : Running EnergyPlus with args: ['-w', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res2/Eplus-env-sub_run4/USA_AZ_Davis-Monthan.AFB.722745_TMY3_Random_1.64655725_0.0_0.000345045547.epw', '-d', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res2/Eplus-env-sub_run4/output', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res2/Eplus-env-sub_run4/5ZoneAutoDXVAV.epJSON']
# (RolloutWorker pid=15343) [ENVIRONMENT] (INFO) : Episode 4 started.
# (RolloutWorker pid=15343) [SIMULATOR] (INFO) : handlers are ready.
# (RolloutWorker pid=15343) [SIMULATOR] (INFO) : System is ready.
# Progress: |*--------------------------------------------------------------------------------------------------| 1%
# Progress: |*--------------------------------------------------------------------------------------------------| 1%
# Progress: |**-------------------------------------------------------------------------------------------------| 2%
# Progress: |**-------------------------------------------------------------------------------------------------| 2%
# Progress: |**-------------------------------------------------------------------------------------------------| 2%
# Progress: |***------------------------------------------------------------------------------------------------| 3%
# Progress: |********-------------------------------------------------------------------------------------------| 8%
# Progress: |***------------------------------------------------------------------------------------------------| 3%
# Progress: |****-----------------------------------------------------------------------------------------------| 4%
# Progress: |****-----------------------------------------------------------------------------------------------| 4%
# Progress: |*****----------------------------------------------------------------------------------------------| 5%
# Progress: |*****----------------------------------------------------------------------------------------------| 5%
# Progress: |*********************************------------------------------------------------------------------| 33%
# Progress: |***********************************----------------------------------------------------------------| 35%
# Progress: |******---------------------------------------------------------------------------------------------| 6%
# Progress: |***************************************************************************************************| 99%
# (RolloutWorker pid=15344) #----------------------------------------------------------------------------------------------# [repeated 2x across cluster]
# (RolloutWorker pid=15344) [ENVIRONMENT] (INFO) : Starting a new episode... [5zone-hot-continuous-stochastic-v1] [Episode 4]
# (RolloutWorker pid=15344) [MODELING] (INFO) : Episode directory created [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run4]
# (RolloutWorker pid=15344) [MODELING] (INFO) : Weather file USA_AZ_Davis-Monthan.AFB.722745_TMY3.epw used.
# (RolloutWorker pid=15344) [MODELING] (INFO) : Adapting weather to building model. [USA_AZ_Davis-Monthan.AFB.722745_TMY3.epw]
# (RolloutWorker pid=15344) [ENVIRONMENT] (INFO) : Saving episode output path... [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run4/output]
# (RolloutWorker pid=15344) [SIMULATOR] (INFO) : Running EnergyPlus with args: ['-w', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run4/USA_AZ_Davis-Monthan.AFB.722745_TMY3_Random_1.64655725_0.0_0.000345045547.epw', '-d', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run4/output', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run4/5ZoneAutoDXVAV.epJSON']
# (RolloutWorker pid=15344) [ENVIRONMENT] (INFO) : Episode 4 started.
# (RolloutWorker pid=15344) [SIMULATOR] (INFO) : handlers are ready.
# (RolloutWorker pid=15344) [SIMULATOR] (INFO) : System is ready.
# Progress: |*--------------------------------------------------------------------------------------------------| 1% [repeated 6x across cluster]
# Progress: |**-------------------------------------------------------------------------------------------------| 2% [repeated 6x across cluster]
# Progress: |***------------------------------------------------------------------------------------------------| 3% [repeated 4x across cluster]
# Progress: |****-----------------------------------------------------------------------------------------------| 4% [repeated 6x across cluster]
# Progress: |*******--------------------------------------------------------------------------------------------| 7%
# Progress: |*****----------------------------------------------------------------------------------------------| 5% [repeated 6x across cluster]
# Progress: |********-------------------------------------------------------------------------------------------| 8%
# Progress: |******---------------------------------------------------------------------------------------------| 6% [repeated 5x across cluster]
# Progress: |*********------------------------------------------------------------------------------------------| 9%
# Progress: |**********-----------------------------------------------------------------------------------------| 10%
# Progress: |***********----------------------------------------------------------------------------------------| 11%
# Progress: |************---------------------------------------------------------------------------------------| 12%
# Progress: |*******--------------------------------------------------------------------------------------------| 7% [repeated 7x across cluster]
# Progress: |********-------------------------------------------------------------------------------------------| 8% [repeated 7x across cluster]
# Progress: |*********------------------------------------------------------------------------------------------| 9% [repeated 5x across cluster]
# Progress: |*************--------------------------------------------------------------------------------------| 13%
# Progress: |**********-----------------------------------------------------------------------------------------| 10% [repeated 7x across cluster]
# Progress: |**************-------------------------------------------------------------------------------------| 14%
# Progress: |***********----------------------------------------------------------------------------------------| 11% [repeated 7x across cluster]
# Progress: |***************------------------------------------------------------------------------------------| 15%
# Progress: |****************-----------------------------------------------------------------------------------| 16%
# Progress: |*****************----------------------------------------------------------------------------------| 17%
# Progress: |************---------------------------------------------------------------------------------------| 12% [repeated 5x across cluster]
# Progress: |*************--------------------------------------------------------------------------------------| 13% [repeated 7x across cluster]
# Progress: |******************---------------------------------------------------------------------------------| 18%
# Progress: |**************-------------------------------------------------------------------------------------| 14% [repeated 7x across cluster]
# Progress: |*******************--------------------------------------------------------------------------------| 19%
# Progress: |***************------------------------------------------------------------------------------------| 15% [repeated 5x across cluster]
# Progress: |****************-----------------------------------------------------------------------------------| 16% [repeated 7x across cluster]
# Progress: |********************-------------------------------------------------------------------------------| 20%
# Progress: |*****************----------------------------------------------------------------------------------| 17% [repeated 7x across cluster]
# Progress: |*********************------------------------------------------------------------------------------| 21%
# Progress: |**********************-----------------------------------------------------------------------------| 22%
# Progress: |***********************----------------------------------------------------------------------------| 23%
# Progress: |***********************----------------------------------------------------------------------------| 23%
# Progress: |******************---------------------------------------------------------------------------------| 18% [repeated 5x across cluster]
# Progress: |*******************--------------------------------------------------------------------------------| 19% [repeated 7x across cluster]
# Progress: |********************-------------------------------------------------------------------------------| 20% [repeated 7x across cluster]
# Progress: |************************---------------------------------------------------------------------------| 24%
# Progress: |*********************------------------------------------------------------------------------------| 21% [repeated 5x across cluster]
# Progress: |*************************--------------------------------------------------------------------------| 25%
# Progress: |**********************-----------------------------------------------------------------------------| 22% [repeated 7x across cluster]
# Progress: |**************************-------------------------------------------------------------------------| 26%
# Progress: |***********************----------------------------------------------------------------------------| 23% [repeated 6x across cluster]
# Progress: |***************************------------------------------------------------------------------------| 27%
# Progress: |****************************-----------------------------------------------------------------------| 28%
# Progress: |************************---------------------------------------------------------------------------| 24% [repeated 5x across cluster]
# Progress: |*************************--------------------------------------------------------------------------| 25% [repeated 7x across cluster]
# Progress: |******************************---------------------------------------------------------------------| 30%
# Progress: |**************************-------------------------------------------------------------------------| 26% [repeated 7x across cluster]
# Progress: |*******************************--------------------------------------------------------------------| 31%
# Progress: |***************************------------------------------------------------------------------------| 27% [repeated 5x across cluster]
# Progress: |********************************-------------------------------------------------------------------| 32%
# Progress: |****************************-----------------------------------------------------------------------| 29% [repeated 15x across cluster]
# Progress: |*********************************------------------------------------------------------------------| 33%
# Progress: |**********************************-----------------------------------------------------------------| 34%
# Progress: |***********************************----------------------------------------------------------------| 35%
# Progress: |******************************---------------------------------------------------------------------| 30% [repeated 5x across cluster]
# Progress: |*******************************--------------------------------------------------------------------| 31% [repeated 7x across cluster]
# Progress: |********************************-------------------------------------------------------------------| 32% [repeated 7x across cluster]
# Progress: |************************************---------------------------------------------------------------| 36%
# Progress: |*************************************--------------------------------------------------------------| 37%
# Progress: |*********************************------------------------------------------------------------------| 33% [repeated 5x across cluster]
# Progress: |**********************************-----------------------------------------------------------------| 34% [repeated 7x across cluster]
# Progress: |**************************************-------------------------------------------------------------| 38%
# Progress: |***************************************------------------------------------------------------------| 39%
# Progress: |****************************************-----------------------------------------------------------| 40%
# Progress: |***********************************----------------------------------------------------------------| 35% [repeated 7x across cluster]
# Progress: |************************************---------------------------------------------------------------| 36% [repeated 5x across cluster]
# Progress: |*************************************--------------------------------------------------------------| 37% [repeated 7x across cluster]
# Progress: |*****************************************----------------------------------------------------------| 41%
# Progress: |**************************************-------------------------------------------------------------| 38% [repeated 7x across cluster]
# Progress: |******************************************---------------------------------------------------------| 42%
# Progress: |*******************************************--------------------------------------------------------| 43%
# Progress: |***************************************------------------------------------------------------------| 39% [repeated 5x across cluster]
# Progress: |****************************************-----------------------------------------------------------| 40% [repeated 7x across cluster]
# Progress: |********************************************-------------------------------------------------------| 44%
# Progress: |*********************************************------------------------------------------------------| 45%
# Progress: |**********************************************-----------------------------------------------------| 46%
# Progress: |*****************************************----------------------------------------------------------| 41% [repeated 7x across cluster]
# Progress: |******************************************---------------------------------------------------------| 42% [repeated 5x across cluster]
# Progress: |***********************************************----------------------------------------------------| 47%
# Progress: |*******************************************--------------------------------------------------------| 43% [repeated 7x across cluster]
# Progress: |************************************************---------------------------------------------------| 48%
# Progress: |********************************************-------------------------------------------------------| 44% [repeated 7x across cluster]
# Progress: |*************************************************--------------------------------------------------| 49%
# Progress: |*********************************************------------------------------------------------------| 45% [repeated 5x across cluster]
# Progress: |**************************************************-------------------------------------------------| 50%
# Progress: |**********************************************-----------------------------------------------------| 46% [repeated 7x across cluster]
# Progress: |***************************************************------------------------------------------------| 51%
# Progress: |***********************************************----------------------------------------------------| 47% [repeated 7x across cluster]
# Progress: |****************************************************-----------------------------------------------| 52%
# Progress: |************************************************---------------------------------------------------| 48% [repeated 5x across cluster]
# Progress: |*****************************************************----------------------------------------------| 53%
# Progress: |*************************************************--------------------------------------------------| 49% [repeated 7x across cluster]
# Progress: |******************************************************---------------------------------------------| 54%
# Progress: |**************************************************-------------------------------------------------| 50% [repeated 7x across cluster]
# Progress: |*******************************************************--------------------------------------------| 55%
# Progress: |***************************************************------------------------------------------------| 51% [repeated 7x across cluster]
# Progress: |********************************************************-------------------------------------------| 56%
# Progress: |****************************************************-----------------------------------------------| 52% [repeated 5x across cluster]
# Progress: |*****************************************************----------------------------------------------| 53% [repeated 7x across cluster]
# Progress: |*********************************************************------------------------------------------| 58%
# Progress: |******************************************************---------------------------------------------| 54% [repeated 7x across cluster]
# Progress: |***********************************************************----------------------------------------| 59%
# Progress: |*******************************************************--------------------------------------------| 55% [repeated 5x across cluster]
# Progress: |************************************************************---------------------------------------| 60%
# Progress: |********************************************************-------------------------------------------| 57% [repeated 15x across cluster]
# Progress: |*************************************************************--------------------------------------| 61%
# Progress: |**************************************************************-------------------------------------| 62%
# Progress: |**************************************************************-------------------------------------| 62%
# Progress: |***************************************************************------------------------------------| 63%
# Progress: |*********************************************************------------------------------------------| 58% [repeated 5x across cluster]
# Progress: |***********************************************************----------------------------------------| 59% [repeated 7x across cluster]
# Progress: |************************************************************---------------------------------------| 60% [repeated 7x across cluster]
# Progress: |****************************************************************-----------------------------------| 64%
# Progress: |*****************************************************************----------------------------------| 65%
# Progress: |*************************************************************--------------------------------------| 61% [repeated 5x across cluster]
# Progress: |**************************************************************-------------------------------------| 62% [repeated 6x across cluster]
# (RolloutWorker pid=15344)
# Progress: |******************************************************************---------------------------------| 66%
# Progress: |***************************************************************------------------------------------| 63% [repeated 7x across cluster]
# Progress: |*******************************************************************--------------------------------| 67%
# Progress: |********************************************************************-------------------------------| 68%
# Progress: |*********************************************************************------------------------------| 69%
# Progress: |****************************************************************-----------------------------------| 64% [repeated 5x across cluster]
# Progress: |*****************************************************************----------------------------------| 65% [repeated 7x across cluster]
# Progress: |******************************************************************---------------------------------| 66% [repeated 7x across cluster]
# Progress: |**********************************************************************-----------------------------| 70%
# Progress: |***********************************************************************----------------------------| 71%
# Progress: |*******************************************************************--------------------------------| 67% [repeated 5x across cluster]
# Progress: |************************************************************************---------------------------| 72%
# Progress: |********************************************************************-------------------------------| 68% [repeated 7x across cluster]
# Progress: |*************************************************************************--------------------------| 73%
# Progress: |**************************************************************************-------------------------| 74%
# Progress: |*********************************************************************------------------------------| 69% [repeated 7x across cluster]
# Progress: |**********************************************************************-----------------------------| 70% [repeated 5x across cluster]
# Progress: |***********************************************************************----------------------------| 71% [repeated 7x across cluster]
# Progress: |***************************************************************************------------------------| 75%
# Progress: |************************************************************************---------------------------| 72% [repeated 7x across cluster]
# Progress: |****************************************************************************-----------------------| 76%
# Progress: |*****************************************************************************----------------------| 77%
# Progress: |*************************************************************************--------------------------| 73% [repeated 5x across cluster]
# Progress: |**************************************************************************-------------------------| 74% [repeated 7x across cluster]
# Progress: |******************************************************************************---------------------| 78%
# Progress: |*******************************************************************************--------------------| 79%
# Progress: |********************************************************************************-------------------| 80%
# Progress: |***************************************************************************------------------------| 75% [repeated 7x across cluster]
# Progress: |****************************************************************************-----------------------| 76% [repeated 5x across cluster]
# Progress: |*****************************************************************************----------------------| 77% [repeated 7x across cluster]
# Progress: |*********************************************************************************------------------| 81%
# Progress: |******************************************************************************---------------------| 78% [repeated 7x across cluster]
# Progress: |**********************************************************************************-----------------| 82%
# Progress: |***********************************************************************************----------------| 83%
# Progress: |*******************************************************************************--------------------| 79% [repeated 5x across cluster]
# Progress: |********************************************************************************-------------------| 80% [repeated 7x across cluster]
# Progress: |************************************************************************************---------------| 84%
# Progress: |*************************************************************************************--------------| 85%
# Progress: |**************************************************************************************-------------| 86%
# Progress: |*********************************************************************************------------------| 81% [repeated 7x across cluster]
# Progress: |**********************************************************************************-----------------| 82% [repeated 5x across cluster]
# Progress: |***************************************************************************************------------| 87%
# Progress: |***********************************************************************************----------------| 83% [repeated 7x across cluster]
# Progress: |****************************************************************************************-----------| 88%
# Progress: |************************************************************************************---------------| 84% [repeated 7x across cluster]
# Progress: |*****************************************************************************************----------| 89%
# Progress: |*************************************************************************************--------------| 85% [repeated 5x across cluster]
# Progress: |******************************************************************************************---------| 90%
# Progress: |******************************************************************************************---------| 90%
# Progress: |*******************************************************************************************--------| 91%
# Progress: |**************************************************************************************-------------| 86% [repeated 7x across cluster]
# Progress: |***************************************************************************************------------| 87% [repeated 7x across cluster]
# Progress: |********************************************************************************************-------| 92%
# Progress: |****************************************************************************************-----------| 88% [repeated 5x across cluster]
# Progress: |*********************************************************************************************------| 93%
# Progress: |*****************************************************************************************----------| 89% [repeated 7x across cluster]
# Progress: |**********************************************************************************************-----| 94%
# Progress: |******************************************************************************************---------| 90% [repeated 6x across cluster]
# Progress: |***********************************************************************************************----| 95%
# Progress: |*******************************************************************************************--------| 91% [repeated 5x across cluster]
# Progress: |************************************************************************************************---| 96%
# Progress: |*************************************************************************************************--| 97%
# Progress: |********************************************************************************************-------| 92% [repeated 7x across cluster]
# Progress: |*********************************************************************************************------| 93% [repeated 7x across cluster]
# Progress: |**************************************************************************************************-| 98%
# Progress: |**********************************************************************************************-----| 94% [repeated 5x across cluster]
# Progress: |***************************************************************************************************| 99%
# Progress: |***********************************************************************************************----| 95% [repeated 7x across cluster]
# Progress: |************************************************************************************************---| 96% [repeated 7x across cluster]
# (RolloutWorker pid=15343)
# (RolloutWorker pid=15343) #----------------------------------------------------------------------------------------------#
# (RolloutWorker pid=15343) [ENVIRONMENT] (INFO) : Starting a new episode... [5zone-hot-continuous-stochastic-v1] [Episode 5]
# (RolloutWorker pid=15343) #----------------------------------------------------------------------------------------------#
# (RolloutWorker pid=15343) [MODELING] (INFO) : Episode directory created [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res2/Eplus-env-sub_run5]
# (RolloutWorker pid=15343) [MODELING] (INFO) : Weather file USA_AZ_Davis-Monthan.AFB.722745_TMY3.epw used.
# (RolloutWorker pid=15343) [MODELING] (INFO) : Adapting weather to building model. [USA_AZ_Davis-Monthan.AFB.722745_TMY3.epw]
# Progress: |*************************************************************************************************--| 97% [repeated 5x across cluster]
# (RolloutWorker pid=15343) [ENVIRONMENT] (INFO) : Saving episode output path... [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res2/Eplus-env-sub_run5/output]
# (RolloutWorker pid=15343) [SIMULATOR] (INFO) : Running EnergyPlus with args: ['-w', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res2/Eplus-env-sub_run5/USA_AZ_Davis-Monthan.AFB.722745_TMY3_Random_1.64655725_0.0_0.000345045547.epw', '-d', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res2/Eplus-env-sub_run5/output', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res2/Eplus-env-sub_run5/5ZoneAutoDXVAV.epJSON']
# (RolloutWorker pid=15343) [ENVIRONMENT] (INFO) : Episode 5 started.
# (RolloutWorker pid=15343) [SIMULATOR] (INFO) : handlers are ready.
# (RolloutWorker pid=15343) [SIMULATOR] (INFO) : System is ready.
# Progress: |*--------------------------------------------------------------------------------------------------| 1%
# Progress: |**-------------------------------------------------------------------------------------------------| 2%
# Progress: |***------------------------------------------------------------------------------------------------| 3%
# Progress: |**************************************************************************************************-| 98% [repeated 7x across cluster]
# Progress: |***************************************************************************************************| 99% [repeated 7x across cluster]
# (RolloutWorker pid=15344)
# Progress: |****-----------------------------------------------------------------------------------------------| 4%
# (RolloutWorker pid=15344) #----------------------------------------------------------------------------------------------# [repeated 2x across cluster]
# (RolloutWorker pid=15344) [ENVIRONMENT] (INFO) : Starting a new episode... [5zone-hot-continuous-stochastic-v1] [Episode 5]
# (RolloutWorker pid=15344) [MODELING] (INFO) : Episode directory created [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run5]
# (RolloutWorker pid=15344) [MODELING] (INFO) : Weather file USA_AZ_Davis-Monthan.AFB.722745_TMY3.epw used.
# (RolloutWorker pid=15344) [MODELING] (INFO) : Adapting weather to building model. [USA_AZ_Davis-Monthan.AFB.722745_TMY3.epw]
# (RolloutWorker pid=15344) [ENVIRONMENT] (INFO) : Saving episode output path... [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run5/output]
# (RolloutWorker pid=15344) [SIMULATOR] (INFO) : Running EnergyPlus with args: ['-w', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run5/USA_AZ_Davis-Monthan.AFB.722745_TMY3_Random_1.64655725_0.0_0.000345045547.epw', '-d', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run5/output', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run5/5ZoneAutoDXVAV.epJSON']
# (RolloutWorker pid=15344) [ENVIRONMENT] (INFO) : Episode 5 started.
# Progress: |*****----------------------------------------------------------------------------------------------| 5%
# (RolloutWorker pid=15344)
# (RolloutWorker pid=15344) [SIMULATOR] (INFO) : handlers are ready.
# (RolloutWorker pid=15344) [SIMULATOR] (INFO) : System is ready.
# Progress: |*--------------------------------------------------------------------------------------------------| 1% [repeated 7x across cluster]
# Progress: |******---------------------------------------------------------------------------------------------| 6%
# Progress: |**-------------------------------------------------------------------------------------------------| 2% [repeated 7x across cluster]
# Progress: |*******--------------------------------------------------------------------------------------------| 7%
# Progress: |***------------------------------------------------------------------------------------------------| 3% [repeated 5x across cluster]
# Progress: |********-------------------------------------------------------------------------------------------| 8%
# Progress: |*********------------------------------------------------------------------------------------------| 9%
# Progress: |****-----------------------------------------------------------------------------------------------| 4% [repeated 7x across cluster]
# Progress: |*****----------------------------------------------------------------------------------------------| 5% [repeated 7x across cluster]
# Progress: |******---------------------------------------------------------------------------------------------| 6% [repeated 5x across cluster]
# Progress: |**********-----------------------------------------------------------------------------------------| 10%
# Progress: |*******--------------------------------------------------------------------------------------------| 7% [repeated 7x across cluster]
# Progress: |***********----------------------------------------------------------------------------------------| 11%
# Progress: |***********----------------------------------------------------------------------------------------| 11%
# Progress: |********-------------------------------------------------------------------------------------------| 8% [repeated 7x across cluster]
# Progress: |************---------------------------------------------------------------------------------------| 12%
# Progress: |*************--------------------------------------------------------------------------------------| 13%
# Progress: |**************-------------------------------------------------------------------------------------| 14%
# Progress: |*********------------------------------------------------------------------------------------------| 9% [repeated 5x across cluster]
# Progress: |**********-----------------------------------------------------------------------------------------| 10% [repeated 7x across cluster]
# Progress: |***********----------------------------------------------------------------------------------------| 11% [repeated 6x across cluster]
# Progress: |***************------------------------------------------------------------------------------------| 15%
# Progress: |************---------------------------------------------------------------------------------------| 12% [repeated 5x across cluster]
# Progress: |****************-----------------------------------------------------------------------------------| 16%
# Progress: |*************--------------------------------------------------------------------------------------| 13% [repeated 7x across cluster]
# Progress: |*****************----------------------------------------------------------------------------------| 17%
# ...
# (RolloutWorker pid=15343) [ENVIRONMENT] (INFO) : Episode 32 started.
# (RolloutWorker pid=15343) [SIMULATOR] (INFO) : handlers are ready.
# (RolloutWorker pid=15343) [SIMULATOR] (INFO) : System is ready.
# Progress: |*--------------------------------------------------------------------------------------------------| 1%
# Progress: |**-------------------------------------------------------------------------------------------------| 2%
# Progress: |***------------------------------------------------------------------------------------------------| 3%
# Progress: |*************************************************************************************************--| 97% [repeated 5x across cluster]
# Progress: |**************************************************************************************************-| 98% [repeated 7x across cluster]
# Progress: |***************************************************************************************************| 99% [repeated 7x across cluster]
# (RolloutWorker pid=15344)
# (RolloutWorker pid=15344) #----------------------------------------------------------------------------------------------# [repeated 2x across cluster]
# (RolloutWorker pid=15344) [ENVIRONMENT] (INFO) : Starting a new episode... [5zone-hot-continuous-stochastic-v1] [Episode 32]
# (RolloutWorker pid=15344) [MODELING] (INFO) : Episode directory created [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run32]
# (RolloutWorker pid=15344) [MODELING] (INFO) : Weather file USA_AZ_Davis-Monthan.AFB.722745_TMY3.epw used.
# (RolloutWorker pid=15344) [MODELING] (INFO) : Adapting weather to building model. [USA_AZ_Davis-Monthan.AFB.722745_TMY3.epw]
# Progress: |****-----------------------------------------------------------------------------------------------| 4%
# (RolloutWorker pid=15344) [ENVIRONMENT] (INFO) : Saving episode output path... [/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run32/output]
# (RolloutWorker pid=15344) [SIMULATOR] (INFO) : Running EnergyPlus with args: ['-w', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run32/USA_AZ_Davis-Monthan.AFB.722745_TMY3_Random_1.64655725_0.0_0.000345045547.epw', '-d', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run32/output', '/home/luigi/Documents/SmartEnergyOptimizationRL/Eplus-env-Eplus-5zone-hot-continuous-stochastic-v1-res1/Eplus-env-sub_run32/5ZoneAutoDXVAV.epJSON']
# (RolloutWorker pid=15344) [ENVIRONMENT] (INFO) : Episode 32 started.
# (RolloutWorker pid=15344) [SIMULATOR] (INFO) : handlers are ready.
# (RolloutWorker pid=15344) [SIMULATOR] (INFO) : System is ready.
# Progress: |*--------------------------------------------------------------------------------------------------| 1% [repeated 7x across cluster]
# Progress: |*****----------------------------------------------------------------------------------------------| 5%
# Progress: |**-------------------------------------------------------------------------------------------------| 2% [repeated 7x across cluster]
# Progress: |******---------------------------------------------------------------------------------------------| 6%
# Progress: |*******--------------------------------------------------------------------------------------------| 7%
# Progress: |***------------------------------------------------------------------------------------------------| 3% [repeated 5x across cluster]
# Progress: |********-------------------------------------------------------------------------------------------| 8%
# Progress: |*********------------------------------------------------------------------------------------------| 9%
# Progress: |****-----------------------------------------------------------------------------------------------| 4% [repeated 7x across cluster]
# Progress: |*****----------------------------------------------------------------------------------------------| 5% [repeated 7x across cluster]
# Progress: |******---------------------------------------------------------------------------------------------| 6% [repeated 5x across cluster]
# Progress: |**********-----------------------------------------------------------------------------------------| 10%
# Progress: |*******--------------------------------------------------------------------------------------------| 7% [repeated 7x across cluster]
# Progress: |***********----------------------------------------------------------------------------------------| 11%
# Progress: |********-------------------------------------------------------------------------------------------| 8% [repeated 7x across cluster]
# Progress: |************---------------------------------------------------------------------------------------| 12%
# Progress: |************---------------------------------------------------------------------------------------| 12%
# Progress: |*************--------------------------------------------------------------------------------------| 13%
# Progress: |**************-------------------------------------------------------------------------------------| 14%
# Progress: |*********------------------------------------------------------------------------------------------| 9% [repeated 5x across cluster]
# Progress: |**********-----------------------------------------------------------------------------------------| 10% [repeated 7x across cluster]
# Progress: |***********----------------------------------------------------------------------------------------| 11% [repeated 7x across cluster]
# Progress: |***************------------------------------------------------------------------------------------| 15%
# Progress: |************---------------------------------------------------------------------------------------| 12% [repeated 4x across cluster]
# Progress: |****************-----------------------------------------------------------------------------------| 16%
# Progress: |*************--------------------------------------------------------------------------------------| 13% [repeated 7x across cluster]
# Progress: |*****************----------------------------------------------------------------------------------| 17%
# Progress: |**************-------------------------------------------------------------------------------------| 14% [repeated 7x across cluster]
# Progress: |******************---------------------------------------------------------------------------------| 18%
# Progress: |*******************--------------------------------------------------------------------------------| 19%
# Progress: |********************-------------------------------------------------------------------------------| 20%
# Progress: |***************------------------------------------------------------------------------------------| 15% [repeated 5x across cluster]
# Progress: |****************-----------------------------------------------------------------------------------| 16% [repeated 7x across cluster]
# Progress: |*****************----------------------------------------------------------------------------------| 17% [repeated 7x across cluster]
# Progress: |*********************------------------------------------------------------------------------------| 21%
# Progress: |**********************-----------------------------------------------------------------------------| 22%
# Progress: |******************---------------------------------------------------------------------------------| 18% [repeated 5x across cluster]
# Progress: |*******************--------------------------------------------------------------------------------| 19% [repeated 7x across cluster]
# Progress: |***********************----------------------------------------------------------------------------| 23%
# Progress: |********************-------------------------------------------------------------------------------| 20% [repeated 7x across cluster]
# Progress: |************************---------------------------------------------------------------------------| 24%
# Progress: |*************************--------------------------------------------------------------------------| 25%
# Progress: |**************************-------------------------------------------------------------------------| 26%
# Progress: |*********************------------------------------------------------------------------------------| 21% [repeated 5x across cluster]
# Progress: |**********************-----------------------------------------------------------------------------| 22% [repeated 7x across cluster]
# Progress: |***********************----------------------------------------------------------------------------| 23% [repeated 7x across cluster]
# Progress: |***************************------------------------------------------------------------------------| 27%
# Progress: |****************************-----------------------------------------------------------------------| 28%
# Progress: |************************---------------------------------------------------------------------------| 24% [repeated 5x across cluster]
# Progress: |*************************--------------------------------------------------------------------------| 25% [repeated 7x across cluster]
# Progress: |******************************---------------------------------------------------------------------| 30%
# Progress: |*******************************--------------------------------------------------------------------| 31%
# Progress: |**************************-------------------------------------------------------------------------| 26% [repeated 7x across cluster]
# Progress: |***************************------------------------------------------------------------------------| 27% [repeated 5x across cluster]
# Progress: |****************************-----------------------------------------------------------------------| 29% [repeated 15x across cluster]
# Progress: |********************************-------------------------------------------------------------------| 32%
# Progress: |******************************---------------------------------------------------------------------| 30% [repeated 5x across cluster]
# Progress: |*******************************--------------------------------------------------------------------| 31% [repeated 7x across cluster]
# Progress: |*********************************------------------------------------------------------------------| 33%
# Progress: |**********************************-----------------------------------------------------------------| 34%
# Progress: |***********************************----------------------------------------------------------------| 35%
# Progress: |************************************---------------------------------------------------------------| 36%
# Progress: |*************************************--------------------------------------------------------------| 37%
# Progress: |********************************-------------------------------------------------------------------| 32% [repeated 7x across cluster]
# Progress: |*********************************------------------------------------------------------------------| 33% [repeated 5x across cluster]
# Progress: |**********************************-----------------------------------------------------------------| 34% [repeated 7x across cluster]
# Progress: |**************************************-------------------------------------------------------------| 38%
# Progress: |***********************************----------------------------------------------------------------| 35% [repeated 7x across cluster]
# Progress: |************************************---------------------------------------------------------------| 36% [repeated 5x across cluster]
# Progress: |***************************************------------------------------------------------------------| 39%
# Progress: |*************************************--------------------------------------------------------------| 37% [repeated 7x across cluster]
# Progress: |****************************************-----------------------------------------------------------| 40%
# Progress: |*****************************************----------------------------------------------------------| 41%
# Progress: |******************************************---------------------------------------------------------| 42%
# Progress: |*******************************************--------------------------------------------------------| 43%
# Progress: |**************************************-------------------------------------------------------------| 38% [repeated 7x across cluster]
# Progress: |***************************************------------------------------------------------------------| 39% [repeated 5x across cluster]
# Progress: |****************************************-----------------------------------------------------------| 40% [repeated 7x across cluster]
# Progress: |*****************************************----------------------------------------------------------| 41% [repeated 7x across cluster]
# Progress: |********************************************-------------------------------------------------------| 44%
# Progress: |******************************************---------------------------------------------------------| 42% [repeated 5x across cluster]
# Progress: |*********************************************------------------------------------------------------| 45%
# Progress: |*******************************************--------------------------------------------------------| 43% [repeated 7x across cluster]
# Progress: |**********************************************-----------------------------------------------------| 46%
# Progress: |***********************************************----------------------------------------------------| 47%
# Progress: |************************************************---------------------------------------------------| 48%
# Progress: |*************************************************--------------------------------------------------| 49%
# Progress: |********************************************-------------------------------------------------------| 44% [repeated 7x across cluster]
# Progress: |*********************************************------------------------------------------------------| 45% [repeated 5x across cluster]
# Progress: |**********************************************-----------------------------------------------------| 46% [repeated 7x across cluster]
# Progress: |***********************************************----------------------------------------------------| 47% [repeated 7x across cluster]
# Progress: |**************************************************-------------------------------------------------| 50%
# Progress: |************************************************---------------------------------------------------| 48% [repeated 5x across cluster]
# Progress: |***************************************************------------------------------------------------| 51%
# Progress: |****************************************************-----------------------------------------------| 52%
# Progress: |*****************************************************----------------------------------------------| 53%
# Progress: |*****************************************************----------------------------------------------| 53%
# Progress: |******************************************************---------------------------------------------| 54%
# 2024-03-14 21:35:05,964	WARNING deprecation.py:50 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!

# %%
# Plotting
plt.figure(figsize=(10, 5))

# Plot the rewards
plt.plot(np.load('results/PPO_allDefault_rewards_500_episodes.npy'), label='Default PPO')
plt.plot(np.load('results/PPO_activation_gamma99_rewards_500_episodes.npy'), label='Dropout Activation PPO')
plt.plot(np.load('results/Curr_Learning_gamma99_rewards_500_episodes.npy'), label='Curriculum Learning $\gamma=99$')
plt.plot(np.load('results/Curr_Learning_gamma90_rewards_500_episodes.npy'), label='Curriculum Learning $\gamma=90$')
plt.plot(np.load('results/Curr_Learning_gamma80_rewards_500_episodes.npy'), label='Curriculum Learning $\gamma=80$')

plt.xlabel('Episode')
plt.ylabel('Mean Reward')
plt.title('Mean Reward per Episode')
plt.legend()
plt.savefig('results/plot5.png')
plt.show()
